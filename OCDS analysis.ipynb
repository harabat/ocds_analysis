# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Prep" data-toc-modified-id="Prep-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Prep</a></span></li><li><span><a href="#Comparing-csv-and-excel" data-toc-modified-id="Comparing-csv-and-excel-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Comparing <code>csv</code> and <code>excel</code></a></span><ul class="toc-item"><li><span><a href="#Load-data" data-toc-modified-id="Load-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Initial-comparison" data-toc-modified-id="Initial-comparison-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Initial comparison</a></span></li><li><span><a href="#Standardise-columns" data-toc-modified-id="Standardise-columns-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Standardise columns</a></span></li></ul></li><li><span><a href="#json" data-toc-modified-id="json-3"><span class="toc-item-num">3&nbsp;&nbsp;</span><code>json</code></a></span><ul class="toc-item"><li><span><a href="#Load" data-toc-modified-id="Load-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#uri,-license,-version,-publisher,-extensions,-publicationPolicy" data-toc-modified-id="uri,-license,-version,-publisher,-extensions,-publicationPolicy-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><code>uri</code>, <code>license</code>, <code>version</code>, <code>publisher</code>, <code>extensions</code>, <code>publicationPolicy</code></a></span></li><li><span><a href="#releases" data-toc-modified-id="releases-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><code>releases</code></a></span><ul class="toc-item"><li><span><a href="#Flatten-JSON" data-toc-modified-id="Flatten-JSON-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Flatten JSON</a></span></li><li><span><a href="#Explore-a-release" data-toc-modified-id="Explore-a-release-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Explore a release</a></span></li></ul></li></ul></li><li><span><a href="#Quality-control" data-toc-modified-id="Quality-control-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Quality control</a></span><ul class="toc-item"><li><span><a href="#Non-unique-ocid,-release_id,-id-values" data-toc-modified-id="Non-unique-ocid,-release_id,-id-values-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Non-unique <code>ocid</code>, <code>release_id</code>, <code>id</code> values</a></span></li><li><span><a href="#bids.details" data-toc-modified-id="bids.details-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><code>bids.details</code></a></span></li><li><span><a href="#planning.budget.id" data-toc-modified-id="planning.budget.id-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span><code>planning.budget.id</code></a></span></li></ul></li><li><span><a href="#Winner-and-loser-provinces" data-toc-modified-id="Winner-and-loser-provinces-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Winner and loser provinces</a></span><ul class="toc-item"><li><span><a href="#Clean" data-toc-modified-id="Clean-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Clean</a></span><ul class="toc-item"><li><span><a href="#Parties" data-toc-modified-id="Parties-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Parties</a></span></li><li><span><a href="#Localities" data-toc-modified-id="Localities-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Localities</a></span></li><li><span><a href="#Cities" data-toc-modified-id="Cities-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Cities</a></span></li><li><span><a href="#Regions" data-toc-modified-id="Regions-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Regions</a></span></li><li><span><a href="#Save-to-pickle" data-toc-modified-id="Save-to-pickle-5.1.5"><span class="toc-item-num">5.1.5&nbsp;&nbsp;</span>Save to pickle</a></span></li></ul></li><li><span><a href="#Insight" data-toc-modified-id="Insight-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Insight</a></span></li></ul></li><li><span><a href="#Lucky-tenderers" data-toc-modified-id="Lucky-tenderers-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Lucky tenderers</a></span><ul class="toc-item"><li><span><a href="#Clean" data-toc-modified-id="Clean-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Clean</a></span><ul class="toc-item"><li><span><a href="#Extract-roles" data-toc-modified-id="Extract-roles-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Extract roles</a></span></li><li><span><a href="#Save-to-pickle" data-toc-modified-id="Save-to-pickle-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Save to pickle</a></span></li></ul></li><li><span><a href="#Insight" data-toc-modified-id="Insight-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Insight</a></span></li></ul></li><li><span><a href="#Common-contract-amounts" data-toc-modified-id="Common-contract-amounts-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Common contract amounts</a></span><ul class="toc-item"><li><span><a href="#Clean" data-toc-modified-id="Clean-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Clean</a></span></li><li><span><a href="#Insight" data-toc-modified-id="Insight-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Insight</a></span></li></ul></li><li><span><a href="#Number-of-tenderers-vs-amount" data-toc-modified-id="Number-of-tenderers-vs-amount-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Number of tenderers vs amount</a></span></li></ul></div>

# %% [markdown]
# # OCDS analysis

# %% [markdown]
# ## Prep

# %%
import pandas as pd # data analysis

import seaborn as sns # data viz
import altair as alt # data viz

from altair_saver import save # save charts

from pathlib import Path # read and write files

import math # rounding operation

import re # regexes

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## Comparing `csv` and `excel`

# %% [markdown]
# ### Load data

# %%
data_xlsx = pd.read_excel('./data/releases_2022.xlsx', sheet_name=None)

# %%
data_xlsx.keys()
# Out:
# dict_keys(['Metadata', 'Extensions', 'Releases', 'Planning', 'Tender', 'Awards', 'AwardSuppliers', 'Contracts'])

# %%
for key in data_xlsx.keys():
    print(
        f'{key}\n'
        f'\t{data_xlsx[key].columns}\n'
    )

# %% [markdown]
# ### Initial comparison

# %%
def diff_csv_xlsx(csv_dir='./csv/', data_xslx=data_xlsx):
    '''Find differences between 2 DataFrames.'''

    # dict that will contain diffs
    differences = dict()

    # directory with csv files
    csv_dir = Path(csv_dir)

    # iterate over csv files and compare to xlsx
    for file in csv_dir.iterdir():
        file_name = str(file.relative_to(csv_dir)).replace('_2022.csv', '').capitalize()

        if file_name == 'Suppliers':
            file_name = 'AwardSuppliers'

        data_csv = pd.read_csv(file)

        difference = data_csv.compare(data_xlsx[file_name])

        if difference.shape[0] != 0:
            print(file_name)
            differences[file_name] = difference
            
    return differences

# %%
differences = diff_csv_xlsx()
# Out:
# Awards
# Contracts
# Planning
# Tender

# %% [markdown]
# Let's look at the files one by one.

# %%
differences['Awards']
# Out:
#        description          amount
#               self other      self         other
# 179            NaN   NaN   2738.40   2738.399664
# 253            NaN   NaN    176.33    176.332800
# 430            NaN   NaN  14244.69  14244.687000
# 711            NaN   NaN    204.06    204.064000
# 841            NaN   NaN   1838.05   1838.054400
# ...            ...   ...       ...           ...
# 125352         NaN   NaN  73111.87  73111.869500
# 125358         NaN   NaN  73733.33  73733.333200
# 125362         NaN   NaN  80026.76  80026.761700
# 125512         NaN   NaN  28299.74  28299.744000
# 125659         NaN   NaN  66890.30  66890.304000
#
# [55417 rows x 4 columns]

# %%
differences['Awards']['description'].dropna().values
# Out:
# array([['41', 41]], dtype=object)

# %% [markdown]
# For `Awards`, the differences seem to be different types and float precision.

# %%
differences['Contracts']
# Out:
#        contractPeriod_durationInDays          amount
#                                 self other      self     other
# 1                                365   365  54096.00     54096
# 2                                 60    60  15143.26  15143.26
# 3                                 90    90  13893.00     13893
# 4                                 20    20  16800.00     16800
# 5                                122   122  15600.00     15600
# ...                              ...   ...       ...       ...
# 115635                           108   108  12800.00     12800
# 115636                            10    10   5900.00      5900
# 115637                           100   100  30397.44  30397.44
# 115638                           365   365  23575.20   23575.2
# 115639                            90    90   7852.80    7852.8
#
# [20150 rows x 4 columns]

# %% [markdown]
# Same for `Contacts`.

# %% [markdown]
# ### Standardise columns

# %% [markdown]
# Let's standardise the columns to better compare them.

# %%
def standardise_col(df):
    '''Standardise dtypes and float precision in a DataFrame.'''
    
    # infer datatypes
    df = df.convert_dtypes()
    
    # fill missing values with pd.NA
    df = df.fillna(pd.NA)

    for col in df.columns:
        try:
            # try converting to numerical dtype
            df[col] = pd.to_numeric(df[col])
            # round to 2 decimal places
            df[col] = df[col].apply(lambda x: round(x, 2) if pd.notna(x) else x)
        except:
            # if error, convert to string
            df[col] = df[col].apply(str)    
    
    return df

# %%
def diff_csv_xlsx(csv_dir='./data/csv/', data_xslx=data_xlsx):
    '''Find differences between 2 DataFrames.'''

    # dict that will contain diffs
    differences = dict()

    # directory with csv files
    csv_dir = Path(csv_dir)

    # iterate over csv files and compare to xlsx
    for file in csv_dir.iterdir():
        file_name = str(file.relative_to(csv_dir)).replace('_2022.csv', '').capitalize()

        if file_name == 'Suppliers':
            file_name = 'AwardSuppliers'

        data_csv = pd.read_csv(file)
        
        data_csv_std = standardise_col(data_csv)
        data_xlsx_std = standardise_col(data_xlsx[file_name])

        difference = data_csv_std.compare(data_xlsx_std)

        if difference.shape[0] != 0:
            print(file_name)
            differences[file_name] = difference
            
    return differences

# %%
differences = diff_csv_xlsx()
# Out:
# Planning
# Tender

# %% [markdown]
# `Planning` and `Tender` still seem to be problematic here.

# %%
differences['Planning'].head()
# Out:
#                                                rationale  \
#                                                     self
# 681    ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPER...
# 5060   ADQUISICIÓN DE REPUESTOS Y ACCESORIOS PARA CUA...
# 9013   ADQUISICIÓN DE REPUESTOS Y ACCESORIOS INCLUIDO...
# 12103  EJECUCIÓN DE OBRA POR MENOR CUANTÍA EN LAS BAT...
# 13438  ADQUISICION DE BIENES ESTRATEGICOS EN SALUD PA...
#
#
#                                                    other
# 681    ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPER...
# 5060   ADQUISICIÓN DE REPUESTOS Y ACCESORIOS PARA CUA...
# 9013   ADQUISICIÓN DE REPUESTOS Y ACCESORIOS INCLUIDO...
# 12103  EJECUCIÓN DE OBRA POR MENOR CUANTÍA EN LAS BAT...
# 13438  ADQUISICION DE BIENES ESTRATEGICOS EN SALUD PA...

# %%
print(
    f"N of differences in `Planning`: {len(differences['Planning'].iloc[:, :2].dropna())}\n"
    f'Examples:'
)


for i in differences['Planning'].iloc[:, :2].dropna().iloc[0]:
    print('\t', i)
# Out:
# N of differences in `Planning`: 13
# Examples:
# 	 ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPERFUSIÓN EN PACIENTES CRÍTICAMENTE ENFERMOS DEL SERVICIO DE NEFROLOGIA DEL HE1
# 	 ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPERFUSIÓN EN PACIENTES CRÍTICAMENTE ENFERMOS DEL SERVICIO DE NEFROLOGIA DEL HE_x0002_1

# %%
differences['Tender'].head()
# Out:
#                                              description  \
#                                                     self
# 523    ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPER...
# 20438  ADQUISICIÓN DE REPUESTOS Y ACCESORIOS INCLUIDO...
# 31354  ADQUISICION DE BIENES ESTRATEGICOS EN SALUD PA...
# 54056  ADQUISICION DE  MEDICAMENTOS MEDICAMENTOS SIST...
# 56148  “MANTENIMIENTO PREVENTIVO/CORRECTIVO  DE LA IN...
#
#
#                                                    other
# 523    ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPER...
# 20438  ADQUISICIÓN DE REPUESTOS Y ACCESORIOS INCLUIDO...
# 31354  ADQUISICION DE BIENES ESTRATEGICOS EN SALUD PA...
# 54056  ADQUISICION DE  MEDICAMENTOS MEDICAMENTOS SIST...
# 56148  “MANTENIMIENTO PREVENTIVO/CORRECTIVO  DE LA IN...

# %%
print(
    f"N of differences in `Tender`: {len(differences['Tender'].iloc[:, :2].dropna())}\n"
    f'Examples:'
)


for i in differences['Tender'].iloc[:, :2].dropna().iloc[0]:
    print('\t', i)
# Out:
# N of differences in `Tender`: 11
# Examples:
# 	 ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPERFUSIÓN EN PACIENTES CRÍTICAMENTE ENFERMOS DEL SERVICIO DE NEFROLOGIA DEL HE1
# 	 ADQUISICIÓN DE CARTUCHO DE RESINA PARA HEMOPERFUSIÓN EN PACIENTES CRÍTICAMENTE ENFERMOS DEL SERVICIO DE NEFROLOGIA DEL HE_x0002_1

# %% [markdown]
# The `rationale` differences seem to be due to minor encoding problems, so we'll leave this here for now.

# %% [markdown]
# ## `json`

# %% [markdown]
# ### Load

# %%
# %%bash
#
# ocdskit detect-format releases_2022.json
# Out:
# releases_2022.json: a JSON array of release packages

# %% [markdown]
# `releases_2022.json` is a JSON array of [releases](https://standard.open-contracting.org/latest/en/schema/reference/).

# %%
data_json = pd.read_json('./data/releases_2022.json')

# %%
data_json.shape
# Out:
# (138204, 8)

# %%
# dtypes
data_json.convert_dtypes().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138204 entries, 0 to 138203
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   uri                138204 non-null  string
#  1   license            138204 non-null  string
#  2   version            138204 non-null  Float64
#  3   releases           138204 non-null  object
#  4   publisher          138204 non-null  object
#  5   extensions         138204 non-null  object
#  6   publishedDate      138204 non-null  string
#  7   publicationPolicy  138204 non-null  string
# dtypes: Float64(1), object(3), string(4)
# memory usage: 8.6+ MB

# %%
# count unique values
for col in data_json.columns:
    print(
        f'{col}: {len(data_json[col].apply(str).unique())} unique values'
    )
# Out:
# uri: 1 unique values
# license: 1 unique values
# version: 1 unique values
# releases: 138204 unique values
# publisher: 1 unique values
# extensions: 1 unique values
# publishedDate: 25970 unique values
# publicationPolicy: 1 unique values

# %% [markdown]
# Only `releases` and `publishedDate` have more than 1 unique value. Let's have a look at the other columns first.

# %% [markdown]
# ### `uri`, `license`, `version`, `publisher`, `extensions`, `publicationPolicy`

# %%
data_json['uri'][0]
# Out:
# 'https://portal.compraspublicas.gob.ec/sercop/datos_abiertos/'

# %%
data_json['license'][0]
# Out:
# 'https://creativecommons.org/licenses/by/3.0/ec/'

# %%
data_json['version'][0]
# Out:
# 1.1

# %%
pd.json_normalize(data_json['publisher']).drop_duplicates().transpose()
# Out:
#                                                         0
# uid                                           ocds-5wno2w
# uri                    https://www.compraspublicas.gob.ec
# name    Servicio Nacional de Contratación Pública (SER...
# scheme                                               OCDS

# %%
data_json['extensions'][0]
# Out:
# ['https://raw.githubusercontent.com/open-contracting-extensions/ocds_enquiry_extension/master/extension.json',
#  'https://raw.githubusercontent.com/open-contracting-extensions/ocds_lots_extension/master/extension.json',
#  'https://raw.githubusercontent.com/open-contracting-extensions/ocds_techniques_extension/master/extension.json',
#  'https://raw.githubusercontent.com/SERCOPEC/ocds_sercopEnteredValue_extension/master/extension.json',
#  'https://gitlab.com/dncp-opendata/ocds_auctions_extension/raw/master/extension.json',
#  'https://raw.githubusercontent.com/open-contracting-extensions/ocds_valueBreakdown_extension/main/extension.json',
#  'https://raw.githubusercontent.com/open-contracting-extensions/ocds_competitive_extension/master/extension.json',
#  'https://raw.githubusercontent.com/open-contracting-extensions/ocds_bid_extension/master/extension.json']

# %%
data_json['publicationPolicy'][0]
# Out:
# 'https://datosabiertos.compraspublicas.gob.ec/PLATAFORMA/documentos/politica-publicacion-SERCOP-OCDS.pdf'

# %% [markdown]
# ### `releases`

# %% [markdown]
# #### Flatten JSON

# %%
print(
    f'Releases:\n'
    f"    - Type: {set(type(i) for i in data_json['releases'])}\n"
    f"    - Length: {set(len(i) for i in data_json['releases'])}\n"
)
# Out:
# Releases:
#     - Type: {<class 'list'>}
#     - Length: {1}

# %% [markdown]
# `releases` are lists of 1 element.

# %%
# flatten and extract releases
releases = pd.json_normalize(
    data_json['releases'].apply(lambda x: x[0])
)

# %%
# releases.to_pickle('./data/releases.pkl')

releases = pd.read_pickle('./data/releases.pkl')

# %% [markdown]
# #### Explore a release

# %%
releases.fillna(method='ffill').fillna(method='bfill').head().transpose()
# Out:
#                                                                                      0  \
# id                                   SIE-EPM-RPSD-01-2022-793456-2022-02-19T09:56:0...
# tag                                                                         [planning]
# date                                                         2022-02-18T00:00:00-05:00
# ocid                                           ocds-5wno2w-SIE-EPM-RPSD-01-2022-793456
# parties                              [{'id': 'EC-RUC-2360007530001-793456', 'name':...
# language                                                                            es
# initiationType                                                                  tender
# buyer.id                                                   EC-RUC-2360007530001-793456
# buyer.name                           EMPRESA PUBLICA MUNICIPAL REGISTRO DE LA PROPI...
# planning.budget.id                                                              530208
# planning.rationale                   CONTRATACIÓN DEL SERVICIO DE SEGURIDAD Y VIGIL...
# tender.id                                                  SIE-EPMAPAT-004-2022-297776
# tender.lots                          [{'id': '323694', 'title': 'TUBOS, CANOS Y MAN...
# tender.title                                               SIE-EPMAPAT-004-2022-297776
# tender.status                                                                   active
# tender.enquiries                     [{'id': '2634778', 'date': '2022-02-21T00:00:0...
# tender.tenderers                     [{'id': 'EC-RUC-0301170056001-376462', 'name':...
# tender.awardPeriod.endDate                                   2022-03-11T16:30:00-05:00
# tender.awardPeriod.startDate                                 2022-03-09T16:00:00-05:00
# tender.awardPeriod.maxExtentDate                             2022-03-11T16:30:00-05:00
# tender.awardPeriod.durationInDays                                                  2.0
# tender.description                   ADQUISICIÓN DE TUBERÍA Y ACCESORIOS PARA LA EJ...
# tender.hasEnquiries                                                               True
# tender.tenderPeriod.startDate                                2022-02-18T13:00:00-05:00
# tender.awardCriteria                                                     ratedCriteria
# tender.enquiryPeriod.endDate                                 2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.startDate                               2022-02-18T13:00:00-05:00
# tender.enquiryPeriod.maxExtentDate                           2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.durationInDays                                                4.0
# tender.procuringEntity.id                                  EC-RUC-0460028810001-297776
# tender.procuringEntity.name          EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# tender.numberOfTenderers                                                          10.0
# tender.procurementMethod                                                          open
# tender.mainProcurementCategory                                                   goods
# tender.procurementMethodDetails                            Subasta Inversa Electrónica
# awards                               [{'id': '1904407-SIE-EPMAPASD-04-2022', 'date'...
# auctions                             [{'id': 'SIE-EPMAPASD-04-2022-273847-2022-03-2...
# contracts                            [{'id': '2111707-SIE-EPMAPASD-04-2022', 'value...
# tender.items                         [{'id': '3458163-DS-SO', 'unit': {'id': '436',...
# relatedProcesses                     [{'id': 'SERCOP-SELPROV-006-2019-CE-2022000212...
# tender.value.amount                                                              179.2
# tender.value.currency                                                              USD
# tender.competitive                                                                True
# planning.budget.amount.amount                                                 53615.34
# planning.budget.amount.currency                                                    USD
# tender.eligibilityCriteria           Otros Parámetros de Calificación,Experiencia G...
# tender.tenderPeriod.endDate                                  2022-02-18T15:00:00-05:00
# tender.tenderPeriod.maxExtentDate                            2022-02-18T15:00:00-05:00
# tender.tenderPeriod.durationInDays                                                 1.0
# tender.awardCriteriaDetails                                    Calificación por Precio
# bids.statistics                      [{'id': 'MCO-ETAPA-06-2022-bid-statistics-cant...
# bids.details                         [{'id': '5365513-bid-MCS-FMBC-002-2022', 'date...
#
#                                                                                      1  \
# id                                   SIE-EPMAPAT-004-2022-297776-2022-03-10T10:10:1...
# tag                                                                 [planning, tender]
# date                                                         2022-03-10T05:13:12-05:00
# ocid                                           ocds-5wno2w-SIE-EPMAPAT-004-2022-297776
# parties                              [{'id': 'EC-RUC-0460028810001-297776', 'name':...
# language                                                                            es
# initiationType                                                                  tender
# buyer.id                                                   EC-RUC-0460028810001-297776
# buyer.name                           EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# planning.budget.id                                                      75.01.01.009.0
# planning.rationale                   ADQUISICIÓN DE TUBERÍA Y ACCESORIOS PARA LA EJ...
# tender.id                                                  SIE-EPMAPAT-004-2022-297776
# tender.lots                          [{'id': '323694', 'title': 'TUBOS, CANOS Y MAN...
# tender.title                                               SIE-EPMAPAT-004-2022-297776
# tender.status                                                                   active
# tender.enquiries                     [{'id': '2634778', 'date': '2022-02-21T00:00:0...
# tender.tenderers                     [{'id': 'EC-RUC-0301170056001-376462', 'name':...
# tender.awardPeriod.endDate                                   2022-03-11T16:30:00-05:00
# tender.awardPeriod.startDate                                 2022-03-09T16:00:00-05:00
# tender.awardPeriod.maxExtentDate                             2022-03-11T16:30:00-05:00
# tender.awardPeriod.durationInDays                                                  2.0
# tender.description                   ADQUISICIÓN DE TUBERÍA Y ACCESORIOS PARA LA EJ...
# tender.hasEnquiries                                                               True
# tender.tenderPeriod.startDate                                2022-02-18T13:00:00-05:00
# tender.awardCriteria                                                     ratedCriteria
# tender.enquiryPeriod.endDate                                 2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.startDate                               2022-02-18T13:00:00-05:00
# tender.enquiryPeriod.maxExtentDate                           2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.durationInDays                                                4.0
# tender.procuringEntity.id                                  EC-RUC-0460028810001-297776
# tender.procuringEntity.name          EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# tender.numberOfTenderers                                                          10.0
# tender.procurementMethod                                                          open
# tender.mainProcurementCategory                                                   goods
# tender.procurementMethodDetails                            Subasta Inversa Electrónica
# awards                               [{'id': '1904407-SIE-EPMAPASD-04-2022', 'date'...
# auctions                             [{'id': 'SIE-EPMAPASD-04-2022-273847-2022-03-2...
# contracts                            [{'id': '2111707-SIE-EPMAPASD-04-2022', 'value...
# tender.items                         [{'id': '3458163-DS-SO', 'unit': {'id': '436',...
# relatedProcesses                     [{'id': 'SERCOP-SELPROV-006-2019-CE-2022000212...
# tender.value.amount                                                              179.2
# tender.value.currency                                                              USD
# tender.competitive                                                                True
# planning.budget.amount.amount                                                 53615.34
# planning.budget.amount.currency                                                    USD
# tender.eligibilityCriteria           Otros Parámetros de Calificación,Experiencia G...
# tender.tenderPeriod.endDate                                  2022-02-18T15:00:00-05:00
# tender.tenderPeriod.maxExtentDate                            2022-02-18T15:00:00-05:00
# tender.tenderPeriod.durationInDays                                                 1.0
# tender.awardCriteriaDetails                                    Calificación por Precio
# bids.statistics                      [{'id': 'MCO-ETAPA-06-2022-bid-statistics-cant...
# bids.details                         [{'id': '5365513-bid-MCS-FMBC-002-2022', 'date...
#
#                                                                                      2  \
# id                                   SIE-EPMAPASD-04-2022-273847-2022-03-31T10:53:4...
# tag                                                [planning, tender, award, contract]
# date                                                         2022-03-31T05:58:25-05:00
# ocid                                           ocds-5wno2w-SIE-EPMAPASD-04-2022-273847
# parties                              [{'id': 'EC-RUC-2360001250001-273847', 'name':...
# language                                                                            es
# initiationType                                                                  tender
# buyer.id                                                   EC-RUC-2360001250001-273847
# buyer.name                           EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# planning.budget.id                                                          110.530405
# planning.rationale                   SERVICIO DE MANTENIMIENTO MECÁNICO PREVENTIVO,...
# tender.id                                                  SIE-EPMAPASD-04-2022-273847
# tender.lots                          [{'id': '323721', 'title': 'SERVICIOS DE MANTE...
# tender.title                                               SIE-EPMAPASD-04-2022-273847
# tender.status                                                                   active
# tender.enquiries                     [{'id': '2647786', 'date': '2022-03-10T00:00:0...
# tender.tenderers                     [{'id': 'EC-RUC-1711820116001-994410', 'name':...
# tender.awardPeriod.endDate                                   2022-03-22T17:00:00-05:00
# tender.awardPeriod.startDate                                 2022-03-16T18:15:00-05:00
# tender.awardPeriod.maxExtentDate                             2022-03-22T17:00:00-05:00
# tender.awardPeriod.durationInDays                                                  5.0
# tender.description                   SERVICIO DE MANTENIMIENTO MECÁNICO PREVENTIVO,...
# tender.hasEnquiries                                                               True
# tender.tenderPeriod.startDate                                2022-02-18T13:00:00-05:00
# tender.awardCriteria                                                     ratedCriteria
# tender.enquiryPeriod.endDate                                 2022-02-23T13:00:00-05:00
# tender.enquiryPeriod.startDate                               2022-02-18T13:00:00-05:00
# tender.enquiryPeriod.maxExtentDate                           2022-02-23T13:00:00-05:00
# tender.enquiryPeriod.durationInDays                                                5.0
# tender.procuringEntity.id                                  EC-RUC-2360001250001-273847
# tender.procuringEntity.name          EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# tender.numberOfTenderers                                                           5.0
# tender.procurementMethod                                                          open
# tender.mainProcurementCategory                                                services
# tender.procurementMethodDetails                            Subasta Inversa Electrónica
# awards                               [{'id': '1904407-SIE-EPMAPASD-04-2022', 'date'...
# auctions                             [{'id': 'SIE-EPMAPASD-04-2022-273847-2022-03-2...
# contracts                            [{'id': '2111707-SIE-EPMAPASD-04-2022', 'value...
# tender.items                         [{'id': '3458163-DS-SO', 'unit': {'id': '436',...
# relatedProcesses                     [{'id': 'SERCOP-SELPROV-006-2019-CE-2022000212...
# tender.value.amount                                                              179.2
# tender.value.currency                                                              USD
# tender.competitive                                                                True
# planning.budget.amount.amount                                                 53615.34
# planning.budget.amount.currency                                                    USD
# tender.eligibilityCriteria           Otros Parámetros de Calificación,Experiencia G...
# tender.tenderPeriod.endDate                                  2022-02-18T15:00:00-05:00
# tender.tenderPeriod.maxExtentDate                            2022-02-18T15:00:00-05:00
# tender.tenderPeriod.durationInDays                                                 1.0
# tender.awardCriteriaDetails                                    Calificación por Precio
# bids.statistics                      [{'id': 'MCO-ETAPA-06-2022-bid-statistics-cant...
# bids.details                         [{'id': '5365513-bid-MCS-FMBC-002-2022', 'date...
#
#                                                                                      3  \
# id                                   SIE-EPMAPAT-003-2022-297776-2022-10-14T15:17:5...
# tag                                  [planning, tender, award, contract, implementa...
# date                                                         2022-10-14T10:36:55-05:00
# ocid                                           ocds-5wno2w-SIE-EPMAPAT-003-2022-297776
# parties                              [{'id': 'EC-RUC-0460028810001-297776', 'name':...
# language                                                                            es
# initiationType                                                                  tender
# buyer.id                                                   EC-RUC-0460028810001-297776
# buyer.name                           EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# planning.budget.id                                                      75.01.01.011.0
# planning.rationale                   ADQUISICIÓN DE TUBERÍAS Y ACCESORIOS PARA LA E...
# tender.id                                                  SIE-EPMAPAT-003-2022-297776
# tender.lots                          [{'id': '323678', 'title': 'TUBOS, CANOS Y MAN...
# tender.title                                               SIE-EPMAPAT-003-2022-297776
# tender.status                                                                   active
# tender.enquiries                     [{'id': '2635830', 'date': '2022-02-22T00:00:0...
# tender.tenderers                     [{'id': 'EC-RUC-0301170056001-376462', 'name':...
# tender.awardPeriod.endDate                                   2022-03-14T16:30:00-05:00
# tender.awardPeriod.startDate                                 2022-03-09T16:00:00-05:00
# tender.awardPeriod.maxExtentDate                             2022-03-14T16:30:00-05:00
# tender.awardPeriod.durationInDays                                                  5.0
# tender.description                   ADQUISICIÓN DE TUBERÍAS Y ACCESORIOS PARA LA E...
# tender.hasEnquiries                                                               True
# tender.tenderPeriod.startDate                                2022-02-18T13:00:00-05:00
# tender.awardCriteria                                                     ratedCriteria
# tender.enquiryPeriod.endDate                                 2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.startDate                               2022-02-18T13:00:00-05:00
# tender.enquiryPeriod.maxExtentDate                           2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.durationInDays                                                4.0
# tender.procuringEntity.id                                  EC-RUC-0460028810001-297776
# tender.procuringEntity.name          EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# tender.numberOfTenderers                                                           7.0
# tender.procurementMethod                                                          open
# tender.mainProcurementCategory                                                   goods
# tender.procurementMethodDetails                            Subasta Inversa Electrónica
# awards                               [{'id': '1900499-SIE-EPMAPAT-003-2022', 'date'...
# auctions                             [{'id': 'SIE-EPMAPAT-003-2022-297776-2022-03-1...
# contracts                            [{'id': '2138530-SIE-EPMAPAT-003-2022', 'value...
# tender.items                         [{'id': '3449934-DS-SO', 'unit': {'id': '52208...
# relatedProcesses                     [{'id': 'SERCOP-SELPROV-006-2019-CE-2022000212...
# tender.value.amount                                                              179.2
# tender.value.currency                                                              USD
# tender.competitive                                                                True
# planning.budget.amount.amount                                                 53615.34
# planning.budget.amount.currency                                                    USD
# tender.eligibilityCriteria           Otros Parámetros de Calificación,Experiencia G...
# tender.tenderPeriod.endDate                                  2022-02-18T15:00:00-05:00
# tender.tenderPeriod.maxExtentDate                            2022-02-18T15:00:00-05:00
# tender.tenderPeriod.durationInDays                                                 1.0
# tender.awardCriteriaDetails                                    Calificación por Precio
# bids.statistics                      [{'id': 'MCO-ETAPA-06-2022-bid-statistics-cant...
# bids.details                         [{'id': '5365513-bid-MCS-FMBC-002-2022', 'date...
#
#                                                                                      4
# id                                   SIE-EPVZCH-001-2022-347510-2022-02-19T09:56:04...
# tag                                                                         [planning]
# date                                                         2022-02-18T00:00:00-05:00
# ocid                                            ocds-5wno2w-SIE-EPVZCH-001-2022-347510
# parties                              [{'id': 'EC-RUC-1960144970001-347510', 'name':...
# language                                                                            es
# initiationType                                                                  tender
# buyer.id                                                   EC-RUC-1960144970001-347510
# buyer.name                                Empresa Publica de Vialidad Zamora Chinchipe
# planning.budget.id                                                        7.3.02.02.01
# planning.rationale                   CONTRATACIÓN DEL SERVICIO DE TRANSPORTE DE MAT...
# tender.id                                                  SIE-EPMAPAT-003-2022-297776
# tender.lots                          [{'id': '323678', 'title': 'TUBOS, CANOS Y MAN...
# tender.title                                               SIE-EPMAPAT-003-2022-297776
# tender.status                                                                   active
# tender.enquiries                     [{'id': '2635830', 'date': '2022-02-22T00:00:0...
# tender.tenderers                     [{'id': 'EC-RUC-0301170056001-376462', 'name':...
# tender.awardPeriod.endDate                                   2022-03-14T16:30:00-05:00
# tender.awardPeriod.startDate                                 2022-03-09T16:00:00-05:00
# tender.awardPeriod.maxExtentDate                             2022-03-14T16:30:00-05:00
# tender.awardPeriod.durationInDays                                                  5.0
# tender.description                   ADQUISICIÓN DE TUBERÍAS Y ACCESORIOS PARA LA E...
# tender.hasEnquiries                                                               True
# tender.tenderPeriod.startDate                                2022-02-18T13:00:00-05:00
# tender.awardCriteria                                                     ratedCriteria
# tender.enquiryPeriod.endDate                                 2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.startDate                               2022-02-18T13:00:00-05:00
# tender.enquiryPeriod.maxExtentDate                           2022-02-22T13:00:00-05:00
# tender.enquiryPeriod.durationInDays                                                4.0
# tender.procuringEntity.id                                  EC-RUC-0460028810001-297776
# tender.procuringEntity.name          EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y AL...
# tender.numberOfTenderers                                                           7.0
# tender.procurementMethod                                                          open
# tender.mainProcurementCategory                                                   goods
# tender.procurementMethodDetails                            Subasta Inversa Electrónica
# awards                               [{'id': '1900499-SIE-EPMAPAT-003-2022', 'date'...
# auctions                             [{'id': 'SIE-EPMAPAT-003-2022-297776-2022-03-1...
# contracts                            [{'id': '2138530-SIE-EPMAPAT-003-2022', 'value...
# tender.items                         [{'id': '3449934-DS-SO', 'unit': {'id': '52208...
# relatedProcesses                     [{'id': 'SERCOP-SELPROV-006-2019-CE-2022000212...
# tender.value.amount                                                              179.2
# tender.value.currency                                                              USD
# tender.competitive                                                                True
# planning.budget.amount.amount                                                 53615.34
# planning.budget.amount.currency                                                    USD
# tender.eligibilityCriteria           Otros Parámetros de Calificación,Experiencia G...
# tender.tenderPeriod.endDate                                  2022-02-18T15:00:00-05:00
# tender.tenderPeriod.maxExtentDate                            2022-02-18T15:00:00-05:00
# tender.tenderPeriod.durationInDays                                                 1.0
# tender.awardCriteriaDetails                                    Calificación por Precio
# bids.statistics                      [{'id': 'MCO-ETAPA-06-2022-bid-statistics-cant...
# bids.details                         [{'id': '5365513-bid-MCS-FMBC-002-2022', 'date...

# %%
releases['awards'][2]
# Out:
# [{'id': '1904407-SIE-EPMAPASD-04-2022',
#   'date': '2022-03-22T11:44:16-05:00',
#   'items': [{'id': '3458163-DS-SO',
#     'unit': {'id': '436', 'name': 'Unidad', 'scheme': 'SERCOP'},
#     'quantity': 1,
#     'description': 'SERVICIOS DE MANTENIMIENTO Y REPARACION DE VEHICULOS DE MOTOR. ESTOS SERVICIOS PUEDEN INCLUIR LA REVISION DEL MOTOR, LA PUESTA A PUNTO DEL MOTOR, EL AJUSTE Y LA REPARACION DEL CARBURADOR, EL AJUSTE Y LA REPARACION DE LOS ELEMENTOS DE LA DIRECCION, LA REPA',
#     'classification': {'id': '871410011',
#      'scheme': 'CPC',
#      'description': 'SERVICIOS DE MANTENIMIENTO Y REPARACION DE VEHICULOS DE MOTOR. ESTOS SERVICIOS PUEDEN INCLUIR LA REVISION DEL MOTOR, LA PUESTA A PUNTO DEL MOTOR, EL AJUSTE Y LA REPARACION DEL CARBURADOR, EL AJUSTE Y LA REPARACION DE LOS ELEMENTOS DE LA DIRECCION, LA REPA'},
#     'additionalClassifications': [{'id': '87141.00.1',
#       'uri': 'https://www.compraspublicas.gob.ec/ProcesoContratacion/compras/exe/verComProductos_exe.php?tipo=buscar&idProducto=87141.00.1',
#       'scheme': 'CPC',
#       'description': 'SERVICIOS DE MANTENIMIENTO Y REPARACION DE VEHICULOS DE MOTOR. ESTOS SERVICIOS PUEDEN INCLUIR LA REVISION DEL MOTOR, LA PUESTA A PUNTO DEL MOTOR, EL AJUSTE Y LA REPARACION DEL CARBURADOR, EL AJUSTE Y LA REPARACION DE LOS ELEMENTOS DE LA DIRECCION, LA REPA'}]}],
#   'value': {'amount': 107445, 'currency': 'USD'},
#   'suppliers': [{'id': 'EC-RUC-1711820116001-994410',
#     'name': 'MACAY CEVALLOS HERNAN EUDORO'}],
#   'description': 'CUMPLE CON LOS REQUISITOS MINIMOS SOLICITADOS'}]

# %%
releases['auctions'][2]
# Out:
# [{'id': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-auction-1',
#   'period': {'endDate': '2022-03-16T18:30:00-05:00',
#    'startDate': '2022-03-16T18:15:00-05:00'},
#   'stages': [{'id': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-stage-1',
#     'bids': [{'id': '1904383-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:15:41-05:00',
#       'value': {'amount': 125700, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904384-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:17:54-05:00',
#       'value': {'amount': 115000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1803202173001-311164',
#         'name': 'QUINAPALLO CASA JUAN CARLOS'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904385-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:18:12-05:00',
#       'value': {'amount': 125000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1711820116001-994410',
#         'name': 'MACAY CEVALLOS HERNAN EUDORO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904388-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:18:55-05:00',
#       'value': {'amount': 120016, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1718881541001-972501',
#         'name': 'DIAZ ROMERO OSCAR FABRICIO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904389-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:19:21-05:00',
#       'value': {'amount': 112923, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1718881541001-972501',
#         'name': 'DIAZ ROMERO OSCAR FABRICIO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904392-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:20:15-05:00',
#       'value': {'amount': 123700, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904393-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:20:23-05:00',
#       'value': {'amount': 100000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1803202173001-311164',
#         'name': 'QUINAPALLO CASA JUAN CARLOS'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904394-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:21:07-05:00',
#       'value': {'amount': 121700, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904395-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:21:46-05:00',
#       'value': {'amount': 119000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1711820116001-994410',
#         'name': 'MACAY CEVALLOS HERNAN EUDORO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904396-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:22:01-05:00',
#       'value': {'amount': 117500, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904397-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:22:45-05:00',
#       'value': {'amount': 112200, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904398-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:23:34-05:00',
#       'value': {'amount': 111647, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1718881541001-972501',
#         'name': 'DIAZ ROMERO OSCAR FABRICIO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904399-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:25:13-05:00',
#       'value': {'amount': 109000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904409-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:29:50-05:00',
#       'value': {'amount': 106249, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1718881541001-972501',
#         'name': 'DIAZ ROMERO OSCAR FABRICIO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904408-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:29:38-05:00',
#       'value': {'amount': 71000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1803202173001-311164',
#         'name': 'QUINAPALLO CASA JUAN CARLOS'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904407-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:29:27-05:00',
#       'value': {'amount': 107445, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1711820116001-994410',
#         'name': 'MACAY CEVALLOS HERNAN EUDORO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904403-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:27:38-05:00',
#       'value': {'amount': 80000, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1803202173001-311164',
#         'name': 'QUINAPALLO CASA JUAN CARLOS'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904401-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T18:26:45-05:00',
#       'value': {'amount': 107450, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904333-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T17:05:09-05:00',
#       'value': {'amount': 127555, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1711820116001-994410',
#         'name': 'MACAY CEVALLOS HERNAN EUDORO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904301-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T16:42:03-05:00',
#       'value': {'amount': 127079, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1803202173001-311164',
#         'name': 'QUINAPALLO CASA JUAN CARLOS'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904251-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T16:01:18-05:00',
#       'value': {'amount': 127555, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1718881541001-972501',
#         'name': 'DIAZ ROMERO OSCAR FABRICIO'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'},
#      {'id': '1904245-auction-SIE-EPMAPASD-04-2022',
#       'date': '2022-03-16T15:48:03-05:00',
#       'value': {'amount': 127400, 'currency': 'USD'},
#       'tenderers': [{'id': 'EC-RUC-1801175462001-58826',
#         'name': 'ROCHE  CARLOS IVAN'}],
#       'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'}],
#     'title': 'Subasta',
#     'rounds': [{'id': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1',
#       'period': {'endDate': '2022-03-16T18:30:00-05:00',
#        'startDate': '2022-03-16T18:15:00-05:00'}}]}],
#   'status': 'successful',
#   'winningBids': [{'id': '1904407-auction-SIE-EPMAPASD-04-2022',
#     'date': '2022-03-16T18:29:27-05:00',
#     'value': {'amount': 107445, 'currency': 'USD'},
#     'tenderers': [{'id': 'EC-RUC-1711820116001-994410',
#       'name': 'MACAY CEVALLOS HERNAN EUDORO'}],
#     'relatedRound': 'SIE-EPMAPASD-04-2022-273847-2022-03-23T10:18:29.998Z-round-1'}]}]

# %%
releases['parties'][2]
# Out:
# [{'id': 'EC-RUC-2360001250001-273847',
#   'name': 'EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y ALCANTARILLADO DE SANTO DOMINGO',
#   'roles': ['buyer', 'procuringEntity'],
#   'address': {'region': 'SANTO DOMINGO DE LOS TSACHILAS',
#    'locality': 'SANTO DOMINGO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'Av. Tsachila Yanuncay 698 ABRAHAM CALAZACON'},
#   'identifier': {'id': 'EC-RUC-2360001250001-273847',
#    'scheme': 'EC-RUC',
#    'legalName': 'EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y ALCANTARILLADO DE SANTO DOMINGO'},
#   'contactPoint': {'url': 'http://www.epmapasd.gov.ec',
#    'name': 'EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y ALCANTARILLADO DE SANTO DOMINGO'}},
#  {'id': 'EC-RUC-1801175462001-58826',
#   'name': 'ROCHE  CARLOS IVAN',
#   'roles': ['tenderer'],
#   'address': {'region': 'SANTO DOMINGO DE LOS TSACHILAS',
#    'locality': 'SANTO DOMINGO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'AV. TSACHILA RIO BABA S/N VALLE HERMOSO'},
#   'identifier': {'id': 'EC-RUC-1801175462001-58826',
#    'scheme': 'EC-RUC',
#    'legalName': 'ROCHE  CARLOS IVAN'},
#   'contactPoint': {'name': 'ROCHE  CARLOS IVAN'}},
#  {'id': 'EC-RUC-1718881541001-972501',
#   'name': 'DIAZ ROMERO OSCAR FABRICIO',
#   'roles': ['tenderer'],
#   'address': {'region': 'SANTO DOMINGO DE LOS TSACHILAS',
#    'locality': 'SANTO DOMINGO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'MANUEL BORRERO AV. QUEVEDO S/N SANTO DOMINGO DE LOS COLORADOS'},
#   'identifier': {'id': 'EC-RUC-1718881541001-972501',
#    'scheme': 'EC-RUC',
#    'legalName': 'DIAZ ROMERO OSCAR FABRICIO'},
#   'contactPoint': {'name': 'DIAZ ROMERO OSCAR FABRICIO'}},
#  {'id': 'EC-RUC-1711820116001-994410',
#   'name': 'MACAY CEVALLOS HERNAN EUDORO',
#   'roles': ['tenderer', 'supplier'],
#   'address': {'region': 'SANTO DOMINGO DE LOS TSACHILAS',
#    'locality': 'SANTO DOMINGO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'HUMBERTO FIALLOS CESAR LOPEZ 111 BOMBOLI'},
#   'identifier': {'id': 'EC-RUC-1711820116001-994410',
#    'scheme': 'EC-RUC',
#    'legalName': 'MACAY CEVALLOS HERNAN EUDORO'},
#   'contactPoint': {'name': 'MACAY CEVALLOS HERNAN EUDORO'}},
#  {'id': 'EC-RUC-1803202173001-311164',
#   'name': 'QUINAPALLO CASA JUAN CARLOS',
#   'roles': ['tenderer'],
#   'address': {'region': 'SANTO DOMINGO DE LOS TSACHILAS',
#    'locality': 'SANTO DOMINGO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'AV. LOS COLONES CALLE PABLO PICASSO S/N BOMBOLI'},
#   'identifier': {'id': 'EC-RUC-1803202173001-311164',
#    'scheme': 'EC-RUC',
#    'legalName': 'QUINAPALLO CASA JUAN CARLOS'},
#   'contactPoint': {'name': 'QUINAPALLO CASA JUAN CARLOS'}},
#  {'id': 'EC-RUC-1716448095001-484712',
#   'name': 'IBARRA ZAPATA MAYRA ALEJANDRA',
#   'roles': ['tenderer'],
#   'address': {'region': 'SANTO DOMINGO DE LOS TSACHILAS',
#    'locality': 'SANTO DOMINGO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'PUERTO ILA MARCHENA LOTE 11 SANTO DOMINGO DE LOS COLORADOS'},
#   'identifier': {'id': 'EC-RUC-1716448095001-484712',
#    'scheme': 'EC-RUC',
#    'legalName': 'IBARRA ZAPATA MAYRA ALEJANDRA'},
#   'contactPoint': {'name': 'IBARRA ZAPATA MAYRA ALEJANDRA'}}]

# %%
releases['contracts'][2]
# Out:
# [{'id': '2111707-SIE-EPMAPASD-04-2022',
#   'value': {'amount': 107445, 'currency': 'USD'},
#   'period': {'endDate': '2023-03-29T00:00:00-05:00',
#    'startDate': '2022-03-29T00:00:00-05:00',
#    'durationInDays': 365},
#   'status': 'terminated',
#   'awardID': '1904407-SIE-EPMAPASD-04-2022',
#   'dateSigned': '2022-03-29T00:00:00-05:00'}]

# %%
releases['tender.tenderers'][2]
# Out:
# [{'id': 'EC-RUC-1711820116001-994410', 'name': 'MACAY CEVALLOS HERNAN EUDORO'},
#  {'id': 'EC-RUC-1716448095001-484712',
#   'name': 'IBARRA ZAPATA MAYRA ALEJANDRA'},
#  {'id': 'EC-RUC-1718881541001-972501', 'name': 'DIAZ ROMERO OSCAR FABRICIO'},
#  {'id': 'EC-RUC-1801175462001-58826', 'name': 'ROCHE  CARLOS IVAN'},
#  {'id': 'EC-RUC-1803202173001-311164', 'name': 'QUINAPALLO CASA JUAN CARLOS'}]

# %%
releases['tender.lots'][2]
# Out:
# [{'id': '323721',
#   'title': 'SERVICIOS DE MANTENIMIENTO Y REPARACION DE VEHICULOS DE MOTOR',
#   'value': {'amount': 127555.5, 'currency': 'USD'},
#   'techniques': {'hasElectronicAuction': True}}]

# %% [markdown]
# ## Quality control

# %% [markdown]
# ### Non-unique `ocid`, `release_id`, `id` values

# %%
for file in Path('./data/csv/').iterdir():
    data_csv = pd.read_csv(file)
    print(f"Total length of {file}: {len(data_csv)}")

    for col in data_csv.columns:
        if 'id' in col.lower():
            print(
                f"\tDistinct {col}: {len(data_csv[col].unique())}"
            )
    print()
# Out:
# Total length of data/csv/awards_2022.csv: 126214
# 	Distinct ocid: 124770
# 	Distinct release_id: 124770
# 	Distinct id: 126208
#
# Total length of data/csv/releases_2022.csv: 138204
# 	Distinct ocid: 138204
# 	Distinct id: 138204
# 	Distinct buyer_id: 4688
#
# Total length of data/csv/metadata_2022.csv: 1
# 	Distinct PublisherUid: 1
#
# Total length of data/csv/suppliers_2022.csv: 126214
# 	Distinct ocid: 124770
# 	Distinct release_id: 124770
# 	Distinct award_id: 126208
# 	Distinct id: 17734
#
# Total length of data/csv/contracts_2022.csv: 115640
# 	Distinct ocid: 114679
# 	Distinct release_id: 114679
# 	Distinct id: 115634
# 	Distinct awardID: 115634
#
# Total length of data/csv/planning_2022.csv: 42714
# 	Distinct ocid: 42714
# 	Distinct id: 42714
# 	Distinct budget_id: 15307
#
# Total length of data/csv/tender_2022.csv: 129167
# 	Distinct ocid: 129167
# 	Distinct release_id: 129167
# 	Distinct id: 129167
# 	Distinct procuringEntity_id: 2806
#
# Total length of data/csv/extensions_2022.csv: 7

# %% [markdown]
# ### `bids.details`

# %%
duplicates = 0
total = 0

for i,row in pd.json_normalize(releases['bids.details'].dropna()).iterrows():
    total += 1
    distinct = len(row.dropna().drop_duplicates(keep=False))
    
    if distinct == 0:
        duplicates += 1

print(
    f'{duplicates / total:.0%} of bids.details records have duplicate values'
     )
# Out:
# 71% of bids.details records have duplicate values

# %%
duplicates = 0
total = 0

for i,row in pd.json_normalize(releases['bids.statistics'].dropna()).iterrows():
    total += 1
    distinct = len(row.dropna().drop_duplicates(keep=False))
    
    if distinct == 0:
        duplicates += 1

print(
    f'{duplicates / total:.0%} of bids.statistics records have duplicate values'
)
# Out:
# 96% of bids.statistics records have duplicate values

# %% [markdown]
# ### `planning.budget.id`

# %%
releases['planning.budget.id'].dropna().sample(20)
# Out:
# 67285                                             7.3.14.03
# 51216                                                840113
# 132718                                         7.3.08.03.01
# 88945                                                530803
# 6037      2022.320.9006.0000.90.00.000.004.000.0901.5308...
# 99518     2022.320.1427.0000.24.00.054.001.000.1701.8401...
# 79461                                        7.3.36.3.06.01
# 47016                                         840106 730811
# 31613        2022.95.01.C400.420.730204.000.13.01.000.0.000
# 20993                7.5.01.04.01/7.5.01.04.06/7.5.01.04.09
# 19951                03.03.001.001-000-99.99.99.99-84.01.04
# 42980     2022.052.0045.0000.01.00.000.001.000.0101.5304...
# 60290     2022.320.1030.0000.57.00.000.001.000.0201.5304...
# 125943    2022.612.9999.0000.01.00.000.001.000.1701.5304...
# 3794      2022.090.0000.0000.01.00.000.001.000.1701.5302...
# 122750    2022.320.0053.0000.55.00.000.005.000.0601.5304...
# 33258                                                530826
# 49819                                            5110200907
# 59315       03.03.000.360.750105.111.01.03.000.00000000.003
# 92475     2022.070.2016.0000.57.00.000.003.000.0920.5308...
# Name: planning.budget.id, dtype: object

# %% [markdown]
# The format of `planning.budget.id` is very lenient.

# %% [markdown]
# ## Winner and loser provinces

# %% [markdown]
# ### Clean

# %% [markdown]
# #### Parties

# %%
# create a dataframe with all 'parties'
parties = releases.loc[
    releases['tender.procurementMethod'] == 'open',
    'parties'
].dropna().reset_index(drop=True)

# %%
# example of a 'parties' value
parties[0]
# Out:
# [{'id': 'EC-RUC-0460028810001-297776',
#   'name': 'EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y ALCANTARILLADO DE TULCAN',
#   'roles': ['buyer', 'procuringEntity'],
#   'address': {'region': 'CARCHI',
#    'locality': 'TULCAN',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'JUAN RAMON ARELLANO BOLIVAR S/N TULCAN'},
#   'identifier': {'id': 'EC-RUC-0460028810001-297776',
#    'scheme': 'EC-RUC',
#    'legalName': 'EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y ALCANTARILLADO DE TULCAN'},
#   'contactPoint': {'name': 'EMPRESA PUBLICA MUNICIPAL DE AGUA POTABLE Y ALCANTARILLADO DE TULCAN'}},
#  {'id': 'EC-RUC-1791306023001-4266',
#   'name': 'DITECNIA CIA. LTDA. DISTRIBUIDORA TECNICA ASOCIADA',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'postalCode': '1716114',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'AV. ELOY ALFARO DE LAS HIGUERAS N54-67 CHAUPICRUZ (LA CONCEPCION)'},
#   'identifier': {'id': 'EC-RUC-1791306023001-4266',
#    'scheme': 'EC-RUC',
#    'legalName': 'DITECNIA CIA. LTDA. DISTRIBUIDORA TECNICA ASOCIADA'},
#   'contactPoint': {'url': 'http://www.ditecnia.com.ec',
#    'name': 'DITECNIA CIA. LTDA. DISTRIBUIDORA TECNICA ASOCIADA'}},
#  {'id': 'EC-RUC-1790500039001-23944',
#   'name': 'COMERCIAL ELECTROMECANICA IMPORTADORA EXPORTADORA CEMIMEX CIA. LTDA.',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'postalCode': '170518',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'SELVA ALEGRE ULLOA OE3-74 CHAUPICRUZ (LA CONCEPCION)'},
#   'identifier': {'id': 'EC-RUC-1790500039001-23944',
#    'scheme': 'EC-RUC',
#    'legalName': 'COMERCIAL ELECTROMECANICA IMPORTADORA EXPORTADORA CEMIMEX CIA. LTDA.'},
#   'contactPoint': {'url': 'http://www.cemimex.com',
#    'name': 'COMERCIAL ELECTROMECANICA IMPORTADORA EXPORTADORA CEMIMEX CIA. LTDA.'}},
#  {'id': 'EC-RUC-0400579231001-68697',
#   'name': 'Benavides Revelo Silvia Patricia',
#   'roles': ['tenderer'],
#   'address': {'region': 'CARCHI',
#    'locality': 'TULCAN',
#    'postalCode': '040103',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'OLMEDO JUNIN 52069 GONZALEZ SUAREZ'},
#   'identifier': {'id': 'EC-RUC-0400579231001-68697',
#    'scheme': 'EC-RUC',
#    'legalName': 'Benavides Revelo Silvia Patricia'},
#   'contactPoint': {'name': 'Benavides Revelo Silvia Patricia'}},
#  {'id': 'EC-RUC-1792150248001-164961',
#   'name': 'JOSE JALIL & HIJOS REPRESENTACIONES Y COMERCIO CIA. LTDA.',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'postalCode': '170506',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'PASAJE FRAY JOAQUIN AUZ ULTIMAS NOTICIAS E7-08 LA VICENTINA'},
#   'identifier': {'id': 'EC-RUC-1792150248001-164961',
#    'scheme': 'EC-RUC',
#    'legalName': 'JOSE JALIL & HIJOS REPRESENTACIONES Y COMERCIO CIA. LTDA.'},
#   'contactPoint': {'url': 'https://jhjalil.com.ec/',
#    'name': 'JOSE JALIL & HIJOS REPRESENTACIONES Y COMERCIO CIA. LTDA.'}},
#  {'id': 'EC-RUC-0503072951001-267087',
#   'name': 'Jerez Custode Marcelo Alejandro',
#   'roles': ['tenderer'],
#   'address': {'region': 'COTOPAXI',
#    'locality': 'LATACUNGA',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'UNIDAD NACIONAL EL GLADIADOR SN IGNACIO FLORES (PARQUE FLORES)'},
#   'identifier': {'id': 'EC-RUC-0503072951001-267087',
#    'scheme': 'EC-RUC',
#    'legalName': 'Jerez Custode Marcelo Alejandro'},
#   'contactPoint': {'name': 'Jerez Custode Marcelo Alejandro'}},
#  {'id': 'EC-RUC-0301170056001-376462',
#   'name': 'PALAGUACHI GUARTAN INES LUCIA',
#   'roles': ['tenderer'],
#   'address': {'region': 'CAÑAR',
#    'locality': 'BIBLIAN',
#    'countryName': 'ECUADOR',
#    'streetAddress': '  S/N BIBLIAN, CABECERA CANTONAL'},
#   'identifier': {'id': 'EC-RUC-0301170056001-376462',
#    'scheme': 'EC-RUC',
#    'legalName': 'PALAGUACHI GUARTAN INES LUCIA'},
#   'contactPoint': {'name': 'PALAGUACHI GUARTAN INES LUCIA'}},
#  {'id': 'EC-RUC-1792234549001-405818',
#   'name': 'TONELLO SOLUCIONES INTEGRALES CIA. LTDA.',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'PANAMERICANA NORTE CALLE N73B N73-170 CARCELEN'},
#   'identifier': {'id': 'EC-RUC-1792234549001-405818',
#    'scheme': 'EC-RUC',
#    'legalName': 'TONELLO SOLUCIONES INTEGRALES CIA. LTDA.'},
#   'contactPoint': {'url': 'http://www.tonello.ec',
#    'name': 'TONELLO SOLUCIONES INTEGRALES CIA. LTDA.'}},
#  {'id': 'EC-RUC-1721136875001-392193',
#   'name': 'LOACHAMIN CHANO FREDDY DANIEL',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'INGRESO BARRIO ALPAHUMA Y SN S-228 ALANGASI'},
#   'identifier': {'id': 'EC-RUC-1721136875001-392193',
#    'scheme': 'EC-RUC',
#    'legalName': 'LOACHAMIN CHANO FREDDY DANIEL'},
#   'contactPoint': {'name': 'LOACHAMIN CHANO FREDDY DANIEL'}},
#  {'id': 'EC-RUC-1801426063001-221270',
#   'name': 'Perez Gavilanes Robinzon Humberto',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'postalCode': 'EC170129',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'RITTER ENRIQUE AV. LA GASCA N24-36 SANTA PRISCA'},
#   'identifier': {'id': 'EC-RUC-1801426063001-221270',
#    'scheme': 'EC-RUC',
#    'legalName': 'Perez Gavilanes Robinzon Humberto'},
#   'contactPoint': {'name': 'Perez Gavilanes Robinzon Humberto'}},
#  {'id': 'EC-RUC-1802231660001-330316',
#   'name': 'SOLIS GUEVARA SILVIA JEANNETTE',
#   'roles': ['tenderer'],
#   'address': {'region': 'PICHINCHA',
#    'locality': 'QUITO',
#    'countryName': 'ECUADOR',
#    'streetAddress': 'JUAN MOLINEROS AV. ELOY ALFARO C41 EL INCA'},
#   'identifier': {'id': 'EC-RUC-1802231660001-330316',
#    'scheme': 'EC-RUC',
#    'legalName': 'SOLIS GUEVARA SILVIA JEANNETTE'},
#   'contactPoint': {'name': 'SOLIS GUEVARA SILVIA JEANNETTE'}}]

# %% [markdown]
# #### Localities

# %%
def extract_localities(parties):
    '''Extract locality from list of `parties`.'''
    
    localities = []
    
    for release in parties:
        r_localities = set()
        
        for party in release:
            p_id = party['id']
            try:
                p_locality = party['address']['locality']
            except:
                p_locality = pd.NA
            try:
                p_region = party['address']['region']
            except:
                p_region = pd.NA
            try:
                p_country = party['address']['countryName']
            except:
                p_country = pd.NA
            for role in set(party['roles']):
                r_localities.add((p_id, p_locality, p_region, p_country, role))
                
        localities.extend(r_localities)
        
    return localities

# %%
# extract localities from 'parties'
localities = extract_localities(parties)

# %%
# convert to dataframe
localities = pd.DataFrame(
    localities,
    columns=['id', 'city', 'region', 'country', 'role']
)

# %%
# preview of localities
localities.dropna().head()
# Out:
#                             id     city     region  country             role
# 0  EC-RUC-0301170056001-376462  BIBLIAN      CAÑAR  ECUADOR         tenderer
# 1  EC-RUC-0460028810001-297776   TULCAN     CARCHI  ECUADOR  procuringEntity
# 2  EC-RUC-0460028810001-297776   TULCAN     CARCHI  ECUADOR            buyer
# 3   EC-RUC-1790500039001-23944    QUITO  PICHINCHA  ECUADOR         tenderer
# 4  EC-RUC-1721136875001-392193    QUITO  PICHINCHA  ECUADOR         tenderer

# %% [markdown]
# #### Cities

# %%
# count city/role combinations
cities_roles = localities[['city', 'role', 'country']].groupby(
    ['city', 'role'], as_index=False
).count()

# titlecase city names
cities_roles['city'] = cities_roles['city'].apply(str.title)

# rename column
cities_roles = cities_roles.rename(columns={'country': 'count'})

# preview of 'cities_roles'
cities_roles.head()
# Out:
#          city             role  count
# 0  24 De Mayo            buyer     12
# 1  24 De Mayo  procuringEntity     12
# 2  24 De Mayo         supplier      3
# 3  24 De Mayo         tenderer      9
# 4    Aguarico            buyer     31

# %%
# empty Series to hold 'ranks' values
ranks = pd.Series()

for role in cities_roles['role'].unique():
    # rank each city for each role
    rank = cities_roles.loc[
        cities_roles['role'] == role,
        'count'
    ].rank(ascending=False)
    
    # concatenate existing 'ranks' data and new data
    ranks = pd.concat([ranks, rank])
# Out:
# /tmp/ipykernel_6005/3929945126.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ranks = pd.Series()

# %%
# create new 'ranks' column
cities_roles['rank'] = ranks

# %%
# preview
cities_roles.head()
# Out:
#          city             role  count   rank
# 0  24 De Mayo            buyer     12  151.5
# 1  24 De Mayo  procuringEntity     12  151.5
# 2  24 De Mayo         supplier      3  154.0
# 3  24 De Mayo         tenderer      9  158.5
# 4    Aguarico            buyer     31   88.5

# %% [markdown]
# #### Regions

# %%
# count region/role combinations
regions_roles = localities[['region', 'role', 'country']].groupby(
    ['region', 'role'], as_index=False
).count()

# titlecase region names
regions_roles['region'] = regions_roles['region'].apply(str.title)

# rename column
regions_roles = regions_roles.rename(columns={'country': 'count'})

# preview
regions_roles.head()
# Out:
#     region             role  count
# 0    Azuay            buyer   1710
# 1    Azuay  procuringEntity   1710
# 2    Azuay         supplier   1075
# 3    Azuay         tenderer   4931
# 4  Bolivar            buyer    199

# %%
# empty Series to hold 'ranks' values
ranks = pd.Series()

for role in regions_roles['role'].unique():
    # rank each region for each role
    rank = regions_roles.loc[
        regions_roles['role'] == role,
        'count'
    ].rank(ascending=False)
    
    # concatenate existing 'ranks' data and new data
    ranks = pd.concat([ranks, rank])
# Out:
# /tmp/ipykernel_6005/1936230882.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ranks = pd.Series()

# %%
# create new 'ranks' column
regions_roles['rank'] = ranks

# %%
# preview
regions_roles.head()
# Out:
#     region             role  count  rank
# 0    Azuay            buyer   1710   3.0
# 1    Azuay  procuringEntity   1710   3.0
# 2    Azuay         supplier   1075   3.0
# 3    Azuay         tenderer   4931   3.0
# 4  Bolivar            buyer    199  23.0

# %% [markdown]
# #### Save to pickle

# %%
# cities_roles.to_pickle('./data/cities_roles.pkl')
# regions_roles.to_pickle('./data/regions_roles.pkl')

cities_roles = pd.read_pickle('./data/cities_roles.pkl')
regions_roles = pd.read_pickle('./data/regions_roles.pkl')

# %% [markdown]
# ### Insight

# %%
# plot tenderers' cities vs suppliers' cities
chart_cities_roles = alt.Chart(
    data=cities_roles.pivot(index='city', columns='role', values='rank').reset_index()
)\
.mark_circle()\
.encode(
    alt.X('tenderer:Q', title='Rank among tenderers'),
    alt.Y('supplier:Q', title='Rank among supplier'),
    tooltip='city:N'
)\
.properties(
    title='Prevalence of cities among tenderers and suppliers'
)

save(chart_cities_roles, './assets/cities_roles.png')

chart_cities_roles
# Out:
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 0.54ms
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
# plot tenderers' regions vs suppliers' regions
chart_regions_roles = alt.Chart(
    data=regions_roles.pivot(index='region', columns='role', values='rank').reset_index()
)\
.mark_circle()\
.encode(
    alt.X('tenderer:Q', title='Rank among tenderers'),
    alt.Y('supplier:Q', title='Rank among supplier'),
    alt.Color('region:N'),
    tooltip='region:N'
)\
.properties(
    title='Prevalence of regions among tenderers and suppliers'
)

save(chart_regions_roles, './assets/regions_roles.png')

chart_regions_roles
# Out:
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# `Bolivar` is an outlier here: we would have expected it to be much closer to the other provinces in terms of number of suppliers depending on number of tenderers coming from this province.
#
# Given that it ranks 10 among the most common regions that tenderers come from, it should have been closer to being 10 for the most common regions for suppliers. Instead, it is 23rd, or second to last.
#
# By contrast, `Sucumbios` is an outlier in the other direction: given how it ranks among tenderers' provinces, it would have been expected to rank much more poorly among suppliers' provinces.
#
# The agency could use this insight to determine why Bolivar appears so disadvantaged when it comes to open procedures.
#
# Cross-checking this information with [various economic indicators for Ecuador provinces](https://www.scribd.com/document/398970547/Indice-de-Desarrollo-Humano-en-Ecuador) might also be an interesting exploration.

# %% [markdown]
# ## Lucky tenderers

# %% [markdown]
# ### Clean

# %% [markdown]
# #### Extract roles

# %%
def extract_roles(parties):
    '''Extract roles from list of `parties`.'''
    
    roles = []
    
    for release in parties:
        r_roles = set()
        
        for party in release:
            p_id = party['id']
            
            p_name = party['name']
            
            for role in set(party['roles']):
                r_roles.add((p_id, p_name, role))
                
        roles.extend(r_roles)
        
    return roles

# %%
roles = extract_roles(parties)

# %%
# convert to dataframe
roles = pd.DataFrame(
    roles,
    columns=['id', 'name', 'role']
)

# %%
roles_ranks = roles.value_counts().reset_index()

roles_ranks = roles_ranks.rename(columns={0: 'count'})

roles_ranks['name'] = roles_ranks['name'].apply(str.title)

roles_ranks.head()
# Out:
#                             id  \
# 0  EC-RUC-1792841968001-883678
# 1  EC-RUC-1714905237001-699404
# 2  EC-RUC-0291518281001-911245
# 3  EC-RUC-1091752693001-739629
# 4  EC-RUC-1792616646001-901966
#
#                                                 name      role  count
# 0  Seguridad Privada Compañia Nacional Guaranda C...  tenderer    626
# 1                     Mejia Rivera Christian Vicente  tenderer    586
# 2                              Max.Security Cia Ltda  tenderer    578
# 3   Seguridad, Protección Y Vigilancia Cs5 Cia.Ltda.  tenderer    576
# 4                   Pizzeli Textiles Pizzelitex S.A.  tenderer    492

# %%
# empty Series to hold 'ranks' values
ranks = pd.Series()

for role in roles_ranks['role'].unique():
    # rank each city for each role
    rank = roles_ranks.loc[
        roles_ranks['role'] == role,
        'count'
    ].rank(ascending=False)
    
    # concatenate existing 'ranks' data and new data
    ranks = pd.concat([ranks, rank])
    
# create new 'ranks' column
roles_ranks['rank'] = ranks

# preview
roles_ranks.head()
# Out:
# /tmp/ipykernel_6005/1026009392.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ranks = pd.Series()
#                             id  \
# 0  EC-RUC-1792841968001-883678
# 1  EC-RUC-1714905237001-699404
# 2  EC-RUC-0291518281001-911245
# 3  EC-RUC-1091752693001-739629
# 4  EC-RUC-1792616646001-901966
#
#                                                 name      role  count  rank
# 0  Seguridad Privada Compañia Nacional Guaranda C...  tenderer    626   1.0
# 1                     Mejia Rivera Christian Vicente  tenderer    586   2.0
# 2                              Max.Security Cia Ltda  tenderer    578   3.0
# 3   Seguridad, Protección Y Vigilancia Cs5 Cia.Ltda.  tenderer    576   4.0
# 4                   Pizzeli Textiles Pizzelitex S.A.  tenderer    492   5.0

# %%
# example
roles_ranks.loc[roles_ranks['id'] == 'EC-RUC-1711820116001-994410']
# Out:
#                                 id                          name      role  \
# 21678  EC-RUC-1711820116001-994410  Macay Cevallos Hernan Eudoro  supplier
# 21679  EC-RUC-1711820116001-994410  Macay Cevallos Hernan Eudoro  tenderer
#
#        count    rank
# 21678      1  4107.0
# 21679      1  9578.0

# %%
roles_ranks.loc[roles_ranks['role'] == 'supplier'].head()
# Out:
#                              id                              name      role  \
# 27   EC-RUC-0190123626001-40900         Aseguradora Del Sur C. A.  supplier
# 48   EC-RUC-0991410465001-11294  Laboratorio Vida (Labovida) S.A.  supplier
# 94    EC-RUC-1790691810001-4033                       Simed S. A.  supplier
# 95    EC-RUC-1790551350001-4135               Seguros Alianza S A  supplier
# 119   EC-RUC-0991312080001-3759                Fresenius Kabi S.A  supplier
#
#      count  rank
# 27     252   1.0
# 48     203   2.0
# 94     129   3.0
# 95     127   4.0
# 119    112   5.0

# %% [markdown]
# #### Save to pickle

# %%
# roles_ranks.to_pickle('./data/roles_ranks.pkl')

roles_ranks = pd.read_pickle('./data/roles_ranks.pkl')

# %% [markdown]
# ### Insight

# %%
# plot tenderers' regions vs suppliers' regions
chart_ranks_roles = alt.Chart(
    data=roles_ranks.pivot_table(
        index='name', columns='role', values='rank'
    ).reset_index()
)\
.mark_circle()\
.encode(
    alt.X('tenderer:Q', title='Rank among tenderers'),
    alt.Y('supplier:Q', title='Rank among suppliers'),
    tooltip='name:N'
)\
.properties(
    title='Prevalence of specific parties among tenderers and suppliers'
)

save(chart_ranks_roles, './assets/roles_ranks.png')

chart_ranks_roles
# Out:
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# This plot is similar to the previous one: we counted all the occurrences where a party has answered a tender and all the occurrences where it became a supplier, and plotted the former against the latter for each party.
#
# Each dot is a party. The further the dot is to the left, the more times the party has answered a tender. The further the dot is to the bottom, the more times the party has become a supplier (ie won the tender). The aligned dots are due to the way we're assigning ranks: all the top line dots have only been a supplier once, and their rank is an average rank. The second line corresponds to the parties that have been a supplier twice, etc.
#
# The chart shows that there is a positive correlation between tendering and being a supplier (getting contracts): the parties that answer tenders the most are also the ones most likely to be winning contracts.
#
# In a competitive process, one would expect that most businesses would have to answer many tenders before getting a contract. This is what we see with almost all the dots being in the top left half of the plot.
#
# By contrast, any party that is often a supplier but doesn't tender often is unlikely to exist in a competitive market: here, we have only a few dots [0] [1] in the bottom right half of the plot. This could mean many things: it could indicate that the business is extremely good at focusing on the tenders it's most likely to win, or that the business has few competitors for the service that it provides, or, of course, that it is benefitting from corruption.
#
# We would have to look into this more to know.
#
# [0]: https://ecuadornegocios.com/info/sacancela-quishpe-robert-cristobal-1749263
# [1]: https://ecuadornegocios.com/info/textidor-4379978

# %% [markdown]
# ## Common contract amounts

# %% [markdown]
# ### Clean

# %%
contracts = releases.loc[
    releases['tender.procurementMethod'] == 'open',
    'contracts'
]

contracts = contracts.dropna()

contracts.head()
# Out:
# 2     [{'id': '2111707-SIE-EPMAPASD-04-2022', 'value...
# 3     [{'id': '2138530-SIE-EPMAPAT-003-2022', 'value...
# 6     [{'id': '2110468-SIE-FGE-001-2022', 'value': {...
# 7     [{'id': '2114811-SIE-HEJCA-B-17-2022', 'value'...
# 11    [{'id': '2109649-SIE-FI-2022-001', 'value': {'...
# Name: contracts, dtype: object

# %%
contracts[2]
# Out:
# [{'id': '2111707-SIE-EPMAPASD-04-2022',
#   'value': {'amount': 107445, 'currency': 'USD'},
#   'period': {'endDate': '2023-03-29T00:00:00-05:00',
#    'startDate': '2022-03-29T00:00:00-05:00',
#    'durationInDays': 365},
#   'status': 'terminated',
#   'awardID': '1904407-SIE-EPMAPASD-04-2022',
#   'dateSigned': '2022-03-29T00:00:00-05:00'}]

# %%
def extract_contract_info(contracts):
    
    contract_info = dict()
    
    for i, record in contracts.items():
        contract_info[i] = dict()
        
        amounts = 0
        periods = set()
        
        for contract in record:
            amount = contract['value']['amount']
            amounts += amount
            
            period = contract['period']['durationInDays']
            periods.add(period)
            
        contract_info[i]['amounts'] = amounts
        contract_info[i]['periods'] = max(periods)
        
    contract_info = pd.DataFrame(contract_info).transpose()
    
    return contract_info

# %%
contract_info = extract_contract_info(contracts)

# %%
contract_info.sort_values('amounts')
# Out:
#            amounts  periods
# 16092         1.90    300.0
# 71719       790.81    365.0
# 77979      2500.00    131.0
# 28835      3000.00    270.0
# 28819      3000.00    270.0
# ...            ...      ...
# 56884   8199999.97    300.0
# 19082   8754705.96    270.0
# 45409   9374400.00    150.0
# 16145  14243297.04   1095.0
# 22435  29519116.80   1460.0
#
# [11428 rows x 2 columns]

# %% [markdown]
# ### Insight

# %%
chart_amounts = alt.Chart(contract_info)\
.mark_bar()\
.encode(
    alt.X('amounts:Q', title='Amounts', scale=alt.Scale(type='log')),
    alt.Y('count()', title='Counts'),
)\
.properties(
    title='Amounts awarded in contracts, log scale',
    width=600
)

save(chart_amounts, './assets/amounts.png')

chart_amounts
# Out:
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# /home/warehouse/miniconda3/envs/data-ocds/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# This chart aims to show the distribution of contract amounts on open procedures in 2022.
#
# Because the smallest contracts are a few USD, while the few largest are in the dozens of millions of USD, it is easier to see the distribution with a log scale.
#
# Here, we observe that the amounts stated in contracts are clustering around 10k-100k USD, approximatively.

# %% [markdown]
# ## Number of tenderers vs amount

# %%
tenders = pd.read_csv('./csv/tender_2022.csv')

tenders = tenders.loc[tenders['procurementMethod'] == 'open']

tenders = tenders[['value_amount', 'numberOfTenderers']].dropna()

# tenders = tenders.loc[tenders['value_amount'] < 500000]

sns.scatterplot(
    data=tenders,
    x='numberOfTenderers',
    y='value_amount',
)
# Out:
# <AxesSubplot:xlabel='numberOfTenderers', ylabel='value_amount'>
